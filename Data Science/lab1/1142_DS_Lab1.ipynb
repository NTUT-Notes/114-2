# %% [markdown]
# # Install Anaconda 2026.02 ( https://www.anaconda.com/download )

# %% [markdown]
# # Download zip file  (Python3.7) as followings:

# %% [markdown]
# ## Insert figure by ![My photo](picture.png)  under Markdown mode

# %% [markdown]
# ![這是插圖範例](anaconda.png)

# %% [markdown]
# ## Cell的四種功能：Code、Markdown、Raw NBConvert、Heading

# %% [markdown]
# ### Code：程式碼；Markdown用於文字編輯；Raw NBConvert：程式或文字都不被執行；Heading：設定標題。

# %% [markdown]
# ## *常用的Markdown用法*

# %% [markdown]
# ![常用的Markdown用法](markdown.png)

# %% [markdown]
# ## 無序表列方式
# + test1
# + test2
# - test3
# - test4

# %% [markdown]
# ## 有序表列方式
# 1. test1
# 2. test2
# 3. test3
# 4. test4

# %% [markdown]
# [Try the NTUT CSIE Dept. web link](http://csie.ntut.edu.tw/)

# %% [markdown]
# ![這是插圖範例](NTUTCSIE.png)http://csie.ntut.edu.tw/

# %% [markdown]
# ## Math Equation

# %% [markdown]
# $f(x)=x^{2}+2x+1$

# %% [markdown]
# $$\int_a^b f(x)  \, dx $$

# %% [markdown]
# ###  some equation syntax
# 1. Hat: \hat
# 2. Subscript: _{}
# 3. Sum: \sum
# 4. Limits of sum: \limits _{} ^{}
# 5. Beta: \beta

# %% [markdown]
# Example: $\hat{Y} = \hat{\beta}_{0} + \sum\limits_{j=1}^{p}  X_{j}\hat{\beta}_{j}$

# %% [markdown]
# ### More math syntax
# 1. \gamma : Creates gamma symbol
# 2. \displaystyle : Forces display mode. (Ref: Display style in Math mode)
# 3. \frac{}{} : Creates fraction with two curly braces from numerator and denominator.
# 4. <br> : Creates line breaks
# 5. &emsp; : Creates space.
# 6. \Bigg : Helps create parenthesis of big sizes. (Ref: Brackets and Parentheses)
# 7. \partial : Creates partial derivatives symbol

# %% [markdown]
# ${\gamma}_{0} + \frac{1}{2}= \frac{\partial{x}}{\partial{y}} $

# %% [markdown]
# $ \Bigg( \Big( x \Big ) \Bigg )$

# %%
a=2

# %%
a+2
# Out:
# 4

# %%
a**3
# Out:
# 8

# %% [markdown]
# ## 可以使用中文變數

# %%
長=2

# %%
寬=5

# %%
長*寬
# Out:
# 10

# %% [markdown]
# ## 使用"help" 或是 "?" 查詢指令之參考文件說明

# %%
len?
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# # Magic functions in ipython begin with the percent sign (%)

# %%
# %ls
# Out:
# 127.0.0.1-key.pem                       genymotion-logs-20220526-085255.zip
# 127.0.0.1.pem                           go/
# =                                       googletest/
# AndroidStudioProjects/                  home/
# Applications/                           intel/
# Creative Cloud Files/                   java.log.10542
# CroppedFlyImage0001.tiff                java.log.28775
# Desktop/                                java.log.31745
# Desktopcompressed.zip                   java.log.32516
# Documents/                              jgo/
# Downloads/                              labelImg-1.8.1/
# ImageName_ai_s_0A5LCZtt6gLKnHr_11.json  lf5/
# Library/                                localhost-key.pem
# LightGBM/                               localhost.pem
# Movies/                                 matlab_crash_dump.10320-1
# Music/                                  matlab_crash_dump.28038-1
# Pictures/                               matlab_crash_dump.29216-1
# ...

# %%
# %cd C:\Users\TWP\Desktop
# Out:
# [Errno 2] No such file or directory: 'C:UsersTWPDesktop'
# /Users/yangzhelun

# %%
# %cd C:\twp2025
# Out:
# [Errno 2] No such file or directory: 'C:twp2025'
# /Users/yangzhelun

# %%
# %cd
# Out:
# 執行具有 '.venv (3.13.7) (Python 3.13.7)' 的儲存格需要 ipykernel 套件。
#
# 使用所需的套件<a href='command:jupyter.createPythonEnvAndSelectController'>建立 Python 環境</a>。
#
# 或使用命令 '"/home/yfhd/Documents/114-1/Data Structure/HW_01/.venv/bin/python" -m pip install ipykernel -U --force-reinstall' 安裝 'ipykernel'

# %%
# %pwd
# Out:
# '/Users/yangzhelun'

# %%
# %pylab inline
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /opt/homebrew/lib/python3.9/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['square']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
plot([1,-2,3,0])
# Out:
# 執行具有 '.venv (3.13.7) (Python 3.13.7)' 的儲存格需要 ipykernel 套件。
#
# 使用所需的套件<a href='command:jupyter.createPythonEnvAndSelectController'>建立 Python 環境</a>。
#
# 或使用命令 '"/home/yfhd/Documents/114-1/Data Structure/HW_01/.venv/bin/python" -m pip install ipykernel -U --force-reinstall' 安裝 'ipykernel'

# %%
plot(0,0, marker='*', markersize=120, color= 'b', markeredgecolor='r', markeredgewidth = 5 )

# %% [markdown]
# $$You can plot marker of 'o' for circle; 's' for square; '^' for triangle upwards; 'v' for triangle diwbwards; '+' for plus sign $$

# %%
L=[ 1, 2, 3, 4, 5]

# %%
L?
# Out:
# Type:        list
# String form: [1, 2, 3, 4, 5]
# Length:      5
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
def square(a):
    """加上註解說明(triple-quote notation) Return the square of a."""
    return a ** 2

# %%
square?
# Out:
# Signature: square(a)
# Docstring: 加上註解說明(triple-quote notation) Return the square of a.
# File:      /var/folders/64/h1r3_vb512n3l5k6kszv_6xh0000gn/T/ipykernel_23475/416096709.py
# Type:      function

# %% [markdown]
# ## Accessing Source Code with ??

# %%
square??
# Out:
# Signature: square(a)
# Source:
# def square(a):
#     """加上註解說明(triple-quote notation) Return the square of a."""
#     return a ** 2
# File:      /var/folders/64/h1r3_vb512n3l5k6kszv_6xh0000gn/T/ipykernel_23475/416096709.py
# Type:      function

# %% [markdown]
# ## Beyond tab completion: wildcard matching " * " 萬用字元

# %%
*Warning?
# Out:
# BytesWarning
# ComplexWarning
# DeprecationWarning
# FutureWarning
# ImportWarning
# ModuleDeprecationWarning
# PendingDeprecationWarning
# RankWarning
# ResourceWarning
# RuntimeWarning
# SyntaxWarning
# UnicodeWarning
# UserWarning
# VisibleDeprecationWarning
# Warning

# %%
str.*find*?
# Out:
# str.find
# str.rfind

# %% [markdown]
# ## Running External Code: %run   where "%" is the magic command

# %%
# %run myfirst.py
# Out:
# Hello my DS students!

# %% [markdown]
# ## Timing Code Execution: %timeit

# %%
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 211 µs ± 1.79 µs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
range(1000)
# Out:
# range(0, 1000)

# %% [markdown]
# ##  Input and Output History

# %%
import math

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.cos(2)
# Out:
# 執行具有 '.venv (3.13.7) (Python 3.13.7)' 的儲存格需要 ipykernel 套件。
#
# 使用所需的套件<a href='command:jupyter.createPythonEnvAndSelectController'>建立 Python 環境</a>。
#
# 或使用命令 '"/home/yfhd/Documents/114-1/Data Structure/HW_01/.venv/bin/python" -m pip install ipykernel -U --force-reinstall' 安裝 'ipykernel'

# %%
 # %history -n 10-15
# Out:
#   10: %cd C:\Users\TWP\Desktop
#   11: %cd C:\twp2025
#   12: %cd
#   13: %pwd
#   14: %pylab inline
#   15: plot([1,-2,3,0])

# %% [markdown]
# ##  Shell script commands

# %%
# !echo "hello world!"
# Out:
# hello world!

# %%
# !dir
# Out:
# zsh:1: command not found: dir

# %%
# !cd C:\Users\twp\Music
# Out:
# zsh:cd:1: no such file or directory: C:UserstwpMusic

# %%
# !mkdir test1

# %%
# !dir
# Out:
# zsh:1: command not found: dir

# %%
cd test1
# Out:
# /Users/yangzhelun/test1

# %%
# !dir
# Out:
# zsh:1: command not found: dir

# %%
# %cd ..

# %%
# %pwd

# %%
# %ls

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x)
# Out:
# apple
# banana
# cherry

# %%
for x in "banana":
    print(x)
# Out:
# b
# a
# n
# a
# n
# a

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x) 
    if x == "banana":
        break
# Out:
# apple
# banana

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    print(x) 
    if x == "banana":
        break

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    if x == "banana":
        break
    print(x)

# %%
fruits = ["apple", "banana", "cherry"]
for x in fruits:
    if x == "banana":
        continue
    print(x)
# Out:
# apple
# cherry

# %%
for x in range(3):
    print(x)
# Out:
# 0
# 1
# 2

# %%
for x in range(2, 4):
    print(x)
# Out:
# 2
# 3

# %%
for x in range(2, 12, 3):
      print(x)
# Out:
# 2
# 5
# 8
# 11

# %%
adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]
for x in adj:
    for y in fruits:
        print(x, y)
# Out:
# red apple
# red banana
# red cherry
# big apple
# big banana
# big cherry
# tasty apple
# tasty banana
# tasty cherry

# %% [markdown]
# #####  Turn in your Homework 1 (Problem 3) to i-學園 by 3/6/2025. Add your personal information at the first cell by "Markdown" selection.
# Problem 3:  Use Jupyter to write a function of calculating   "Factorial" for an input integer "a". Add some function usage information.
